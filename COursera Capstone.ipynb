# %% [markdown]
# This notebook will mostly be used for the Capstone Project

# %%
Import Pandas as pd
Import Numpy as np
# Out:
#   File "<ipython-input-6-002452b0550f>", line 1
#     Import Pandas as pd
#                 ^
# SyntaxError: invalid syntax

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
